# %%
import os
import pandas as pd

path = os.path.join('data','distritos_2011-2023.xlsx')
distritos = pd.read_excel(path)

# %%
columnNames=['Proyecto de Ley','provincia', 'departamento', 'distrito_propuesto','Periodo','Creado','Tipo']
distritos_propuesto=distritos.loc[:,columnNames]
distritos_propuesto
# Out:
#       Proyecto de Ley      provincia  departamento  distrito_propuesto  \
# 0       06017/2023-CR      EL COLLAO          PUNO          CHIJICHAYA
# 1       05897/2023-CR      CAJAMARCA     CAJAMARCA         CHANTA ALTA
# 2       05262/2022-PE  LA CONVENCION         CUSCO       TAMBO DEL ENE
# 3       05261/2022-PE         SATIPO         JUNIN             RIO ENE
# 4       05260/2022-PE       TAYACAJA  HUANCAVELICA               TOCAS
# ..                ...            ...           ...                 ...
# 626     08089/2020-CR       CARABAYA          PUNO             AZAROMA
# 627     08092/2020-CR        CUTERVO     CAJAMARCA         SINCHIMACHE
# 628     08098/2020-CR       HUAMANGA      AYACUCHO         CCOCHAPAMPA
# 629  07360/2020-CR\t1         LA MAR      AYACUCHO  MAYUNMARKA DE ANCO
# 630     07367/2020-CR        ABANCAY      APURIMAC             SAYWITE
#
#        Periodo Creado                         Tipo
# 0    2021-2023     No      Declaratoria de interés
# 1    2021-2023     No      Declaratoria de interés
# 2    2021-2023     No  Ley de creación de distrito
# 3    2021-2023     No  Ley de creación de distrito
# 4    2021-2023     No  Ley de creación de distrito
# ..         ...    ...                          ...
# 626  2020-2021     No      Declaratoria de interés
# 627  2020-2021     No      Declaratoria de interés
# 628  2020-2021     No      Declaratoria de interés
# 629  2020-2021     No      Declaratoria de interés
# 630  2020-2021     No      Declaratoria de interés
#
# [631 rows x 7 columns]
