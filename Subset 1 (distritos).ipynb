# %%
import os
import pandas as pd

path = os.path.join('data','distritos_2011-2023.xlsx')
distritos = pd.read_excel(path)

# %%
distritos=distritos.set_index('Proyecto de Ley')

# %%
columnNames=['provincia', 'departamento', 'distrito_propuesto','Periodo','Creado']
distritos_propuesto=distritos.loc[:,columnNames]
distritos_propuesto
# Out:
#                       provincia  departamento  distrito_propuesto    Periodo  \
# Proyecto de Ley
# 06017/2023-CR         EL COLLAO          PUNO          CHIJICHAYA  2021-2023
# 05897/2023-CR         CAJAMARCA     CAJAMARCA         CHANTA ALTA  2021-2023
# 05262/2022-PE     LA CONVENCION         CUSCO       TAMBO DEL ENE  2021-2023
# 05261/2022-PE            SATIPO         JUNIN             RIO ENE  2021-2023
# 05260/2022-PE          TAYACAJA  HUANCAVELICA               TOCAS  2021-2023
# ...                         ...           ...                 ...        ...
# 08089/2020-CR          CARABAYA          PUNO             AZAROMA  2020-2021
# 08092/2020-CR           CUTERVO     CAJAMARCA         SINCHIMACHE  2020-2021
# 08098/2020-CR          HUAMANGA      AYACUCHO         CCOCHAPAMPA  2020-2021
# 07360/2020-CR\t1         LA MAR      AYACUCHO  MAYUNMARKA DE ANCO  2020-2021
# 07367/2020-CR           ABANCAY      APURIMAC             SAYWITE  2020-2021
#
#                  Creado
# Proyecto de Ley
# 06017/2023-CR        No
# 05897/2023-CR        No
# 05262/2022-PE        No
# 05261/2022-PE        No
# 05260/2022-PE        No
# ...                 ...
# 08089/2020-CR        No
# 08092/2020-CR        No
# 08098/2020-CR        No
# 07360/2020-CR\t1     No
# 07367/2020-CR        No
#
# [631 rows x 5 columns]

# %%
#Cuando se agrega la columna PROPONENTE
distritos_propuesto['Proponente'].replace('Congreso-Actualización', 'Congreso', inplace=True)
distritos_propuesto
# Out:
#                       provincia  departamento  distrito_propuesto    Periodo  \
# Proyecto de Ley
# 06017/2023-CR         EL COLLAO          PUNO          CHIJICHAYA  2021-2023
# 05897/2023-CR         CAJAMARCA     CAJAMARCA         CHANTA ALTA  2021-2023
# 05262/2022-PE     LA CONVENCION         CUSCO       TAMBO DEL ENE  2021-2023
# 05261/2022-PE            SATIPO         JUNIN             RIO ENE  2021-2023
# 05260/2022-PE          TAYACAJA  HUANCAVELICA               TOCAS  2021-2023
# ...                         ...           ...                 ...        ...
# 08089/2020-CR          CARABAYA          PUNO             AZAROMA  2020-2021
# 08092/2020-CR           CUTERVO     CAJAMARCA         SINCHIMACHE  2020-2021
# 08098/2020-CR          HUAMANGA      AYACUCHO         CCOCHAPAMPA  2020-2021
# 07360/2020-CR\t1         LA MAR      AYACUCHO  MAYUNMARKA DE ANCO  2020-2021
# 07367/2020-CR           ABANCAY      APURIMAC             SAYWITE  2020-2021
#
#                  Creado Proponente
# Proyecto de Ley
# 06017/2023-CR        No   Congreso
# 05897/2023-CR        No   Congreso
# 05262/2022-PE        No  Ejecutivo
# 05261/2022-PE        No  Ejecutivo
# 05260/2022-PE        No  Ejecutivo
# ...                 ...        ...
# 08089/2020-CR        No   Congreso
# 08092/2020-CR        No   Congreso
# 08098/2020-CR        No   Congreso
# 07360/2020-CR\t1     No   Congreso
# 07367/2020-CR        No   Congreso
#
# [631 rows x 6 columns]

# %%
distritos_propuesto['distrito_propuesto'] = distritos_propuesto['distrito_propuesto'].str.split('/')
distritos_propuesto = distritos_propuesto.explode('distrito_propuesto')
distritos_propuesto
# Out:
#                       provincia  departamento  distrito_propuesto    Periodo  \
# Proyecto de Ley
# 06017/2023-CR         EL COLLAO          PUNO          CHIJICHAYA  2021-2023
# 05897/2023-CR         CAJAMARCA     CAJAMARCA         CHANTA ALTA  2021-2023
# 05262/2022-PE     LA CONVENCION         CUSCO       TAMBO DEL ENE  2021-2023
# 05261/2022-PE            SATIPO         JUNIN             RIO ENE  2021-2023
# 05260/2022-PE          TAYACAJA  HUANCAVELICA               TOCAS  2021-2023
# ...                         ...           ...                 ...        ...
# 08089/2020-CR          CARABAYA          PUNO             AZAROMA  2020-2021
# 08092/2020-CR           CUTERVO     CAJAMARCA         SINCHIMACHE  2020-2021
# 08098/2020-CR          HUAMANGA      AYACUCHO         CCOCHAPAMPA  2020-2021
# 07360/2020-CR\t1         LA MAR      AYACUCHO  MAYUNMARKA DE ANCO  2020-2021
# 07367/2020-CR           ABANCAY      APURIMAC             SAYWITE  2020-2021
#
#                  Creado
# Proyecto de Ley
# 06017/2023-CR        No
# 05897/2023-CR        No
# 05262/2022-PE        No
# 05261/2022-PE        No
# 05260/2022-PE        No
# ...                 ...
# 08089/2020-CR        No
# 08092/2020-CR        No
# 08098/2020-CR        No
# 07360/2020-CR\t1     No
# 07367/2020-CR        No
#
# [643 rows x 5 columns]

# %%
distritos_propuesto['distrito_propuesto'] = distritos_propuesto['distrito_propuesto'].str.split('&')
distritos_propuesto = distritos_propuesto.explode('distrito_propuesto')
distritos_propuesto
# Out:
#                       provincia  departamento  distrito_propuesto    Periodo  \
# Proyecto de Ley
# 06017/2023-CR         EL COLLAO          PUNO          CHIJICHAYA  2021-2023
# 05897/2023-CR         CAJAMARCA     CAJAMARCA         CHANTA ALTA  2021-2023
# 05262/2022-PE     LA CONVENCION         CUSCO       TAMBO DEL ENE  2021-2023
# 05261/2022-PE            SATIPO         JUNIN             RIO ENE  2021-2023
# 05260/2022-PE          TAYACAJA  HUANCAVELICA               TOCAS  2021-2023
# ...                         ...           ...                 ...        ...
# 08089/2020-CR          CARABAYA          PUNO             AZAROMA  2020-2021
# 08092/2020-CR           CUTERVO     CAJAMARCA         SINCHIMACHE  2020-2021
# 08098/2020-CR          HUAMANGA      AYACUCHO         CCOCHAPAMPA  2020-2021
# 07360/2020-CR\t1         LA MAR      AYACUCHO  MAYUNMARKA DE ANCO  2020-2021
# 07367/2020-CR           ABANCAY      APURIMAC             SAYWITE  2020-2021
#
#                  Creado
# Proyecto de Ley
# 06017/2023-CR        No
# 05897/2023-CR        No
# 05262/2022-PE        No
# 05261/2022-PE        No
# 05260/2022-PE        No
# ...                 ...
# 08089/2020-CR        No
# 08092/2020-CR        No
# 08098/2020-CR        No
# 07360/2020-CR\t1     No
# 07367/2020-CR        No
#
# [644 rows x 5 columns]

# %%
distritos_propuesto.to_excel(os.path.join("data", "distritos_propuesto_tiempo.xlsx"))

# %%
#columnNames_1=['provincia', 'departamento', 'distrito_propuesto', 'Proyecto de Ley']
#pl = distritos.loc[:,columnNames_1]
#pl
