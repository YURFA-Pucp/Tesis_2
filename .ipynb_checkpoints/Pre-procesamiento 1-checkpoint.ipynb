# %%
import os
import pandas as pd

path = os.path.join('data','distritos_2011-2023.xlsx')
distritos = pd.read_excel(path)

# %%
#distritos=distritos.set_index('Proyecto de Ley')

# %%
columnNames=['provincia', 'departamento', 'distrito_propuesto']
distritos_1=distritos.loc[:,columnNames]

# %%
duplicados = distritos_1.duplicated(keep=False)
f_duplicadas = distritos_1[duplicados]
print(f_duplicadas)
# Out:
#          provincia  departamento    distrito_propuesto
# 1        CAJAMARCA     CAJAMARCA           CHANTA ALTA
# 2    LA CONVENCION         CUSCO         TAMBO DEL ENE
# 3           SATIPO         JUNIN               RIO ENE
# 4         TAYACAJA  HUANCAVELICA                 TOCAS
# 7       LAMBAYEQUE    LAMBAYEQUE  SAN MARTIN DE PORRES
# ..             ...           ...                   ...
# 626       CARABAYA          PUNO               AZAROMA
# 627        CUTERVO     CAJAMARCA           SINCHIMACHE
# 628       HUAMANGA      AYACUCHO           CCOCHAPAMPA
# 629         LA MAR      AYACUCHO    MAYUNMARKA DE ANCO
# 630        ABANCAY      APURIMAC               SAYWITE
#
# [452 rows x 3 columns]

# %%
distritos_1=distritos_1.drop_duplicates()
distritos_1
# Out:
#          provincia  departamento            distrito_propuesto
# 0        EL COLLAO          PUNO                    CHIJICHAYA
# 1        CAJAMARCA     CAJAMARCA                   CHANTA ALTA
# 2    LA CONVENCION         CUSCO                 TAMBO DEL ENE
# 3           SATIPO         JUNIN                       RIO ENE
# 4         TAYACAJA  HUANCAVELICA                         TOCAS
# ..             ...           ...                           ...
# 620     COTABAMBAS      APURIMAC  VICTOR RAUL HAYA DE LA TORRE
# 621    SAN IGNACIO     CAJAMARCA                   ALTO DORADO
# 622       AZANGARO          PUNO           SANTIAGO  DE PUPUJA
# 623        ATALAYA       UCAYALI                  MALDONADILLO
# 624        HUANUCO       HUANUCO       SANTO DOMINGO DE NAUYAN
#
# [337 rows x 3 columns]

# %%
distritos_1 = distritos_1.groupby(['departamento', 'provincia'])['distrito_propuesto']. count().reset_index()
distritos_1
# Out:
#     departamento             provincia  distrito_propuesto
# 0       AMAZONAS                 BAGUA                   1
# 1       AMAZONAS          CONDORCANQUI                   2
# 2       AMAZONAS                  LUYA                   1
# 3       AMAZONAS  RODRIGUEZ DE MENDOZA                   2
# 4       AMAZONAS             UTCUBAMBA                   3
# ..           ...                   ...                 ...
# 107   SAN MARTIN               TOCACHE                   3
# 108        TACNA                 TACNA                   3
# 109       TUMBES                TUMBES                   2
# 110      UCAYALI               ATALAYA                   2
# 111      UCAYALI            PADRE ABAD                   4
#
# [112 rows x 3 columns]

# %%
columnNames_1=['provincia', 'departamento', 'distrito_propuesto', 'Proyecto de Ley']
pl = distritos.loc[:,columnNames_1]
pl
# Out:
#          provincia  departamento  distrito_propuesto   Proyecto de Ley
# 0        EL COLLAO          PUNO          CHIJICHAYA     06017/2023-CR
# 1        CAJAMARCA     CAJAMARCA         CHANTA ALTA     05897/2023-CR
# 2    LA CONVENCION         CUSCO       TAMBO DEL ENE     05262/2022-PE
# 3           SATIPO         JUNIN             RIO ENE     05261/2022-PE
# 4         TAYACAJA  HUANCAVELICA               TOCAS     05260/2022-PE
# ..             ...           ...                 ...               ...
# 626       CARABAYA          PUNO             AZAROMA     08089/2020-CR
# 627        CUTERVO     CAJAMARCA         SINCHIMACHE     08092/2020-CR
# 628       HUAMANGA      AYACUCHO         CCOCHAPAMPA     08098/2020-CR
# 629         LA MAR      AYACUCHO  MAYUNMARKA DE ANCO  07360/2020-CR\t1
# 630        ABANCAY      APURIMAC             SAYWITE     07367/2020-CR
#
# [631 rows x 4 columns]

# %%
pl['distrito_propuesto'] = pl['distrito_propuesto'].str.split(' / ')
pl = pl.explode('distrito_propuesto')
pl
# Out:
#          provincia  departamento  distrito_propuesto   Proyecto de Ley
# 0        EL COLLAO          PUNO          CHIJICHAYA     06017/2023-CR
# 1        CAJAMARCA     CAJAMARCA         CHANTA ALTA     05897/2023-CR
# 2    LA CONVENCION         CUSCO       TAMBO DEL ENE     05262/2022-PE
# 3           SATIPO         JUNIN             RIO ENE     05261/2022-PE
# 4         TAYACAJA  HUANCAVELICA               TOCAS     05260/2022-PE
# ..             ...           ...                 ...               ...
# 626       CARABAYA          PUNO             AZAROMA     08089/2020-CR
# 627        CUTERVO     CAJAMARCA         SINCHIMACHE     08092/2020-CR
# 628       HUAMANGA      AYACUCHO         CCOCHAPAMPA     08098/2020-CR
# 629         LA MAR      AYACUCHO  MAYUNMARKA DE ANCO  07360/2020-CR\t1
# 630        ABANCAY      APURIMAC             SAYWITE     07367/2020-CR
#
# [637 rows x 4 columns]

# %%
pl['distrito_propuesto'] = pl['distrito_propuesto'].str.split('&')
pl = pl.explode('distrito_propuesto')
pl
# Out:
#          provincia  departamento  distrito_propuesto   Proyecto de Ley
# 0        EL COLLAO          PUNO          CHIJICHAYA     06017/2023-CR
# 1        CAJAMARCA     CAJAMARCA         CHANTA ALTA     05897/2023-CR
# 2    LA CONVENCION         CUSCO       TAMBO DEL ENE     05262/2022-PE
# 3           SATIPO         JUNIN             RIO ENE     05261/2022-PE
# 4         TAYACAJA  HUANCAVELICA               TOCAS     05260/2022-PE
# ..             ...           ...                 ...               ...
# 626       CARABAYA          PUNO             AZAROMA     08089/2020-CR
# 627        CUTERVO     CAJAMARCA         SINCHIMACHE     08092/2020-CR
# 628       HUAMANGA      AYACUCHO         CCOCHAPAMPA     08098/2020-CR
# 629         LA MAR      AYACUCHO  MAYUNMARKA DE ANCO  07360/2020-CR\t1
# 630        ABANCAY      APURIMAC             SAYWITE     07367/2020-CR
#
# [638 rows x 4 columns]

# %%
pl = pl.groupby(['departamento', 'provincia', 'distrito_propuesto'])['Proyecto de Ley']. count().reset_index()
pl
# Out:
# Empty DataFrame
# Columns: [departamento, provincia, distrito_propuesto, Proyecto de Ley]
# Index: []

# %%
pl.to_excel(os.path.join("data", "PL.xlsx"))

# %%
pl.nlargest(20,'Proyecto de Ley')
# Out:
#     departamento      provincia                distrito_propuesto  \
# 228        JUNIN         SATIPO                           RIO ENE
# 103     AYACUCHO        LUCANAS       SAN FRANCISCO DE PAMPAMARCA
# 201      HUANUCO        HUANUCO           SANTA ROSA DE SIRABAMBA
# 215      HUANUCO       PACHITEA                       CHINCHAVITO
# 225        JUNIN       HUANCAYO                          LA PUNTA
# 231        JUNIN         SATIPO                       VILLA MARIA
# 248  LA LIBERTAD       TRUJILLO                        EL MILAGRO
# 311         PUNO           PUNO                           SALCEDO
# 116    CAJAMARCA          CHOTA                         LA PUCARA
# 124    CAJAMARCA      HUALGAYOC                       SAN ANTONIO
# 162        CUSCO  LA CONVENCION                     TAMBO DEL ENE
# 235  LA LIBERTAD         CHEPEN                       PACANGUILLA
# 246  LA LIBERTAD       TRUJILLO                     ALTO TRUJILLO
# ...

# %%
distritos_1 = distritos_1.rename(columns={'departamento': 'DEPARTAMEN', 'provincia':'PROVINCIA'})
distritos_1 ["PROVINCIA"] = distritos_1["PROVINCIA"].str.strip()

# %%
distritos_1 [['distrito_propuesto']]=distritos_1 [['distrito_propuesto']]. apply(pd.to_numeric)

# %%
import geopandas as gpd
import os

Peru=gpd.read_file(os.path.join("mapas", "peruMaps.gpkg"), layer='prov')
Peru["PROVINCIA"] = Peru["PROVINCIA"].str.strip()
Peru
# Out:
#     IDDPTO DEPARTAMEN IDPROV         PROVINCIA               CAPITAL FUENTE  \
# 0       01   AMAZONAS   0101       CHACHAPOYAS           CHACHAPOYAS   INEI
# 1       01   AMAZONAS   0102             BAGUA                 BAGUA   INEI
# 2       01   AMAZONAS   0103           BONGARA              JUMBILLA   INEI
# 3       01   AMAZONAS   0104      CONDORCANQUI  SANTA MARIA DE NIEVA   INEI
# 4       01   AMAZONAS   0105              LUYA                 LAMUD   INEI
# ..     ...        ...    ...               ...                   ...    ...
# 191     24     TUMBES   2403         ZARUMILLA             ZARUMILLA   INEI
# 192     25    UCAYALI   2501  CORONEL PORTILLO              PUCALLPA   INEI
# 193     25    UCAYALI   2502           ATALAYA               ATALAYA   INEI
# 194     25    UCAYALI   2503        PADRE ABAD              AGUAYTIA   INEI
# 195     25    UCAYALI   2504             PURUS             ESPERANZA   INEI
#
#                                               geometry
# ...

# %%
theMap=Peru.merge(distritos_1, on=["DEPARTAMEN", "PROVINCIA"], how="outer")
theMap
# Out:
#     IDDPTO DEPARTAMEN IDPROV         PROVINCIA               CAPITAL FUENTE  \
# 0       01   AMAZONAS   0101       CHACHAPOYAS           CHACHAPOYAS   INEI
# 1       01   AMAZONAS   0102             BAGUA                 BAGUA   INEI
# 2       01   AMAZONAS   0103           BONGARA              JUMBILLA   INEI
# 3       01   AMAZONAS   0104      CONDORCANQUI  SANTA MARIA DE NIEVA   INEI
# 4       01   AMAZONAS   0105              LUYA                 LAMUD   INEI
# ..     ...        ...    ...               ...                   ...    ...
# 191     24     TUMBES   2403         ZARUMILLA             ZARUMILLA   INEI
# 192     25    UCAYALI   2501  CORONEL PORTILLO              PUCALLPA   INEI
# 193     25    UCAYALI   2502           ATALAYA               ATALAYA   INEI
# 194     25    UCAYALI   2503        PADRE ABAD              AGUAYTIA   INEI
# 195     25    UCAYALI   2504             PURUS             ESPERANZA   INEI
#
# ...

# %%
columnas_a_actualizar = ["distrito_propuesto"]
theMap[columnas_a_actualizar] = theMap[columnas_a_actualizar].fillna(0)
theMap
# Out:
#     IDDPTO DEPARTAMEN IDPROV         PROVINCIA               CAPITAL FUENTE  \
# 0       01   AMAZONAS   0101       CHACHAPOYAS           CHACHAPOYAS   INEI
# 1       01   AMAZONAS   0102             BAGUA                 BAGUA   INEI
# 2       01   AMAZONAS   0103           BONGARA              JUMBILLA   INEI
# 3       01   AMAZONAS   0104      CONDORCANQUI  SANTA MARIA DE NIEVA   INEI
# 4       01   AMAZONAS   0105              LUYA                 LAMUD   INEI
# ..     ...        ...    ...               ...                   ...    ...
# 191     24     TUMBES   2403         ZARUMILLA             ZARUMILLA   INEI
# 192     25    UCAYALI   2501  CORONEL PORTILLO              PUCALLPA   INEI
# 193     25    UCAYALI   2502           ATALAYA               ATALAYA   INEI
# 194     25    UCAYALI   2503        PADRE ABAD              AGUAYTIA   INEI
# 195     25    UCAYALI   2504             PURUS             ESPERANZA   INEI
#
# ...

# %%
#Data Scaling
columnsToScale=['distrito_propuesto'] # you can add more columns

from sklearn import preprocessing

minmaxSc = preprocessing.MinMaxScaler(feature_range=(0, 10))

minmaxResult = minmaxSc.fit_transform(theMap[columnsToScale])

theMap['Total_minMax']=minmaxResult
theMap
# Out:
#     IDDPTO DEPARTAMEN IDPROV         PROVINCIA               CAPITAL FUENTE  \
# 0       01   AMAZONAS   0101       CHACHAPOYAS           CHACHAPOYAS   INEI
# 1       01   AMAZONAS   0102             BAGUA                 BAGUA   INEI
# 2       01   AMAZONAS   0103           BONGARA              JUMBILLA   INEI
# 3       01   AMAZONAS   0104      CONDORCANQUI  SANTA MARIA DE NIEVA   INEI
# 4       01   AMAZONAS   0105              LUYA                 LAMUD   INEI
# ..     ...        ...    ...               ...                   ...    ...
# 191     24     TUMBES   2403         ZARUMILLA             ZARUMILLA   INEI
# 192     25    UCAYALI   2501  CORONEL PORTILLO              PUCALLPA   INEI
# 193     25    UCAYALI   2502           ATALAYA               ATALAYA   INEI
# 194     25    UCAYALI   2503        PADRE ABAD              AGUAYTIA   INEI
# 195     25    UCAYALI   2504             PURUS             ESPERANZA   INEI
#
# ...

# %%
#Intervalos
import mapclassify 
import numpy as np

np.random.seed(12345) # so we all get the same results!

# let's try 5 intervals
K=4
theVar=theMap.Total_minMax
# same interval width, easy interpretation
ei5 = mapclassify.EqualInterval(theVar, k=K)
# same interval width based on standard deviation, easy - but not as the previous one, poor when high skewness
msd = mapclassify.StdMean(theVar)
# interval width varies, counts per interval are close, not easy to grasp, repeated values complicate cuts                                
q5=mapclassify.Quantiles(theVar,k=K)

# based on similarity, good for multimodal data 
mb5 = mapclassify.MaximumBreaks(theVar, k=K)
# based on similarity, good for skewed data
ht = mapclassify.HeadTailBreaks(theVar) # no K needed
# based on similarity, optimizer
fj5 = mapclassify.FisherJenks(theVar, k=K)
# based on similarity, optimizer
jc5 = mapclassify.JenksCaspall(theVar, k=K)
# based on similarity, optimizer
mp5 = mapclassify.MaxP(theVar, k=K)

# %%
class5 = q5, ei5,msd, ht, mb5, fj5, jc5, mp5
# Collect ADCM for each classifier
fits = np.array([ c.adcm for c in class5])
# Convert ADCM scores to a DataFrame
adcms = pd.DataFrame(fits)
# Add classifier names
adcms['classifier'] = [c.name for c in class5]
# Add column names to the ADCM
adcms.columns = ['ADCM', 'Classifier']
adcms.sort_values('ADCM').plot.barh(x='Classifier')
# Out:
# <Axes: ylabel='Classifier'>

# %%
theMap['Total_mb5'] = mb5.yb
theMap['Total_msd'] = msd.yb

# %%
theMap.to_excel(os.path.join("data", "theMap.xlsx"))

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1, figsize=(10, 10))
theMap.plot(column='Total_mb5', 
        cmap='Reds', 
        categorical=True,
        edgecolor='grey', 
        linewidth=0.1, 
        alpha=0.75, 
        legend=True,
        legend_kwds={'loc':3},
        ax=ax
       )

ax.set_axis_off()
