# %%
import os
import pandas as pd

path = os.path.join('data','distritos_propuesto_tiempo.xlsx')
distritos = pd.read_excel(path)
distritos
# Out:
#       Proyecto de Ley      provincia  departamento  distrito_propuesto  \
# 0       06017/2023-CR      EL COLLAO          PUNO          CHIJICHAYA
# 1       05897/2023-CR      CAJAMARCA     CAJAMARCA         CHANTA ALTA
# 2       05262/2022-PE  LA CONVENCION         CUSCO       TAMBO DEL ENE
# 3       05261/2022-PE         SATIPO         JUNIN             RIO ENE
# 4       05260/2022-PE       TAYACAJA  HUANCAVELICA               TOCAS
# ..                ...            ...           ...                 ...
# 639     08089/2020-CR       CARABAYA          PUNO             AZAROMA
# 640     08092/2020-CR        CUTERVO     CAJAMARCA         SINCHIMACHE
# 641     08098/2020-CR       HUAMANGA      AYACUCHO         CCOCHAPAMPA
# 642  07360/2020-CR\t1         LA MAR      AYACUCHO  MAYUNMARKA DE ANCO
# 643     07367/2020-CR        ABANCAY      APURIMAC             SAYWITE
#
#        Periodo Creado
# 0    2021-2023     No
# 1    2021-2023     No
# 2    2021-2023     No
# ...

# %%
distritos=distritos.set_index('Proyecto de Ley')
duplicados = distritos.duplicated(keep=False)
f_duplicadas = distritos[duplicados]
distritos=distritos.drop_duplicates()
distritos
# Out:
#                       provincia  departamento  distrito_propuesto    Periodo  \
# Proyecto de Ley
# 06017/2023-CR         EL COLLAO          PUNO          CHIJICHAYA  2021-2023
# 05897/2023-CR         CAJAMARCA     CAJAMARCA         CHANTA ALTA  2021-2023
# 05262/2022-PE     LA CONVENCION         CUSCO       TAMBO DEL ENE  2021-2023
# 05261/2022-PE            SATIPO         JUNIN             RIO ENE  2021-2023
# 05260/2022-PE          TAYACAJA  HUANCAVELICA               TOCAS  2021-2023
# ...                         ...           ...                 ...        ...
# 08089/2020-CR          CARABAYA          PUNO             AZAROMA  2020-2021
# 08092/2020-CR           CUTERVO     CAJAMARCA         SINCHIMACHE  2020-2021
# 08098/2020-CR          HUAMANGA      AYACUCHO         CCOCHAPAMPA  2020-2021
# 07360/2020-CR\t1         LA MAR      AYACUCHO  MAYUNMARKA DE ANCO  2020-2021
# 07367/2020-CR           ABANCAY      APURIMAC             SAYWITE  2020-2021
#
#                  Creado
# ...

# %%
#Agregar o quitar columna de acuerdo sea el caso. Por ejemplo cuando se agrega proponente, lo agregamos en el coódigo que sigue:

duplicados = distritos[distritos.duplicated(subset=["provincia", "departamento", "distrito_propuesto", "Periodo"], keep=False)]

# Filtra las filas duplicadas para quedarte con aquellas que tienen al menos un "Sí" en la columna "Creado"
duplicados_filtrados = duplicados[duplicados["Creado"] == "Si"]

# Combina el DataFrame original con las filas no duplicadas y las filas duplicadas filtradas
distritos = pd.concat([distritos[~distritos.index.isin(duplicados.index)], duplicados_filtrados])
distritos
# Out:
#                      provincia  departamento distrito_propuesto    Periodo  \
# Proyecto de Ley
# 06017/2023-CR        EL COLLAO          PUNO         CHIJICHAYA  2021-2023
# 05897/2023-CR        CAJAMARCA     CAJAMARCA        CHANTA ALTA  2021-2023
# 05262/2022-PE    LA CONVENCION         CUSCO      TAMBO DEL ENE  2021-2023
# 05261/2022-PE           SATIPO         JUNIN            RIO ENE  2021-2023
# 05260/2022-PE         TAYACAJA  HUANCAVELICA              TOCAS  2021-2023
# ...                        ...           ...                ...        ...
# 02665/2017-PE    LA CONVENCION         CUSCO        CIELO PUNCO  2016-2019
# 02663/2017-PE    LA CONVENCION         CUSCO      KUMPIRUSHIATO  2016-2019
# 02664/2017-PE    LA CONVENCION         CUSCO            MANITEA  2016-2019
# 02666/2017-PE           LA MAR      AYACUCHO      RIO MAGDALENA  2016-2019
# 02668/2017-PE    LA CONVENCION         CUSCO    UNION ASHANINKA  2016-2019
#
#                 Creado
# Proyecto de Ley
# ...

# %%
distritos.to_excel(os.path.join("data", "distritos_propuesto_tiempo_SD.xlsx"))
